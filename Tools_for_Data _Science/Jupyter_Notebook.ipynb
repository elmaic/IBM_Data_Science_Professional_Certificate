# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # IBM_Data_Science_Professional_Certificate <img style="float: right;" src="IBM-Data-Science-Professional-Certificate.png" width="150" />
# Personal Data Science profesional Certificate course

# %% [markdown]
# # Data Science Tools and Ecosystem
#
# In this notebook, Data Science Tools and Ecosystem are summarized.
#
# Several projects in different laguages will be created and updated
#
# Objectives:
#
# * Popular Languages used in Data Science
# * Different Libraries used for Data Science
# * Diferrent Data Science Tools
# * Basic Arithmetics

# %% [markdown]
# ### Languages
#
# Some of the popular languages that Data Scientists use are:
#
# |Language|Why it is used|
# |:-:|:-:|
# |Python|simplicity, community support, rich ecosystem of libraries and tools, interoperability with other languages, and high-level programming capabilities|
# |R|it has static graphics that produce good-quality data visualizations|
# |SQL|it allows you to work with structured data stored in databases|

# %% [markdown]
# ### Different Libraries used fot Data Science
#
# ||Python|R|
# |---|:-:|:-:|
# |1|TensorFlow|dplyr|
# |2|NumPy|ggplot2|
# |3|SciPy|RSQLite|
# |4|Pandas|Esquisse|
# |5|Matplotlib|Shiny|
# |6|Keras|mlr3|
# |7|SciKit-Learn|Lubridate|
# |8|PyTorch|RCrawler|
# |9|Scrapy|knitr|
# |10|BeautifulSoup|DT|

# %% [markdown]
# ## Data Science Tools
#
# | Data Science Tools |
# |:-:|
# |Tableau|
# |Apache Spark|
# |Apache Hadoop|
# |Jupyter Lab|
# |Jupyter notebook|
# |Power BI|

# %%
x = (3*4)+5 #This a simple arithmetic expression to mutiply then add integers
print(x)
# Out:
# 17

# %%
t = 200 #minutes
h = t/60 #This will convert 200 minutes to hours by diving by 60
print(h)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author:
# Miguel MARTINEZ
